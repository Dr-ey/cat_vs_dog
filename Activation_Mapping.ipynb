# %% [markdown]
# Імпорт бібліотек:

# %%
import numpy
import tensorflow as tf
import cv2
from matplotlib import pyplot
pyplot.rcParams['figure.figsize'] = [15, 10]

# %% [markdown]
# Перелік версій бібліотек, на яких виконано роботу, для вирішень проблем сумісності:

# %%
print(f'numpy     : {numpy.__version__}')
print(f'tensorflow: {tf.__version__}')
print(f'opencv    : {cv2.__version__}')
# Out:
# numpy     : 1.23.5
# tensorflow: 2.9.1
# opencv    : 4.7.0

# %%
model: tf.keras.Model = tf.keras.models.load_model('cat_vs_dog_greed_model', compile=False)
for layer in model.layers:
    layer.treniable = False
model.compile()

# %%
def load_image(filename: str):
    img = cv2.imread(filename)
    img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
    img = img/img.max()
    img = img[:(img.shape[0]//32)*32, :(img.shape[1]//32)*32, :]
    img.shape = (1, img.shape[0], img.shape[1], 3)
    return img

# %%
image_filename = 'data/PetImages/Dog/12208.jpg' # 'data/PetImages/Cat/12209.jpg'

img = load_image(image_filename)
pred = model.predict(img)
class_name = 'Cat' if pred[0].argmax()==0 else 'Dog'
propability = pred[0].max()
pyplot.imshow(img[0])
pyplot.title(f'{class_name}  {propability:.2f}')
pyplot.show()
# Out:
# 1/1 [==============================] - 4s 4s/step

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, None, None,  0           []
#                                  3)]
#
#  convert_to_inner (Conv2D)      (None, None, None,   1216        ['input[0][0]']
#                                 16)
#
#  batch_normalization (BatchNorm  (None, None, None,   64         ['convert_to_inner[0][0]']
#  alization)                     16)
#
#  convolution_0 (Conv2D)         (None, None, None,   25664       ['batch_normalization[0][0]']
#                                 64)
#
#  concentrate_0 (Conv2D)         (None, None, None,   1040        ['convolution_0[0][0]']
#                                 16)
#
#  out_pooling_0 (MaxPooling2D)   (None, None, None,   0           ['concentrate_0[0][0]']
#                                 16)
#
#  normalisation_0 (BatchNormaliz  (None, None, None,   64         ['out_pooling_0[0][0]']
#  ation)                         16)
#
#  start_pooling_0 (MaxPooling2D)  (None, None, None,   0          ['batch_normalization[0][0]']
#                                 16)
#
#  summator_0 (Add)               (None, None, None,   0           ['normalisation_0[0][0]',
#                                 16)                               'start_pooling_0[0][0]']
#
#  convolution_1 (Conv2D)         (None, None, None,   25664       ['summator_0[0][0]']
#                                 64)
#
#  concentrate_1 (Conv2D)         (None, None, None,   1040        ['convolution_1[0][0]']
#                                 16)
#
#  out_pooling_1 (MaxPooling2D)   (None, None, None,   0           ['concentrate_1[0][0]']
#                                 16)
#
#  normalisation_1 (BatchNormaliz  (None, None, None,   64         ['out_pooling_1[0][0]']
#  ation)                         16)
#
#  start_pooling_1 (MaxPooling2D)  (None, None, None,   0          ['summator_0[0][0]']
#                                 16)
#
#  summator_1 (Add)               (None, None, None,   0           ['normalisation_1[0][0]',
#                                 16)                               'start_pooling_1[0][0]']
#
#  convolution_2 (Conv2D)         (None, None, None,   25664       ['summator_1[0][0]']
#                                 64)
#
#  concentrate_2 (Conv2D)         (None, None, None,   1040        ['convolution_2[0][0]']
#                                 16)
#
#  out_pooling_2 (MaxPooling2D)   (None, None, None,   0           ['concentrate_2[0][0]']
#                                 16)
#
#  normalisation_2 (BatchNormaliz  (None, None, None,   64         ['out_pooling_2[0][0]']
#  ation)                         16)
#
#  start_pooling_2 (MaxPooling2D)  (None, None, None,   0          ['summator_1[0][0]']
#                                 16)
#
#  summator_2 (Add)               (None, None, None,   0           ['normalisation_2[0][0]',
#                                 16)                               'start_pooling_2[0][0]']
#
#  convolution_3 (Conv2D)         (None, None, None,   25664       ['summator_2[0][0]']
#                                 64)
#
#  concentrate_3 (Conv2D)         (None, None, None,   1040        ['convolution_3[0][0]']
#                                 16)
#
#  out_pooling_3 (MaxPooling2D)   (None, None, None,   0           ['concentrate_3[0][0]']
#                                 16)
#
#  normalisation_3 (BatchNormaliz  (None, None, None,   64         ['out_pooling_3[0][0]']
#  ation)                         16)
#
#  start_pooling_3 (MaxPooling2D)  (None, None, None,   0          ['summator_2[0][0]']
#                                 16)
#
#  summator_3 (Add)               (None, None, None,   0           ['normalisation_3[0][0]',
#                                 16)                               'start_pooling_3[0][0]']
#
#  convolution_4 (Conv2D)         (None, None, None,   25664       ['summator_3[0][0]']
#                                 64)
#
#  concentrate_4 (Conv2D)         (None, None, None,   1040        ['convolution_4[0][0]']
#                                 16)
#
#  out_pooling_4 (MaxPooling2D)   (None, None, None,   0           ['concentrate_4[0][0]']
#                                 16)
#
#  normalisation_4 (BatchNormaliz  (None, None, None,   64         ['out_pooling_4[0][0]']
#  ation)                         16)
#
#  start_pooling_4 (MaxPooling2D)  (None, None, None,   0          ['summator_3[0][0]']
#                                 16)
#
#  summator_4 (Add)               (None, None, None,   0           ['normalisation_4[0][0]',
#                                 16)                               'start_pooling_4[0][0]']
#
#  to_one_shape (Resizing)        (None, 8, 8, 16)     0           ['summator_4[0][0]']
#
#  concentrate_out_C (Conv2D)     (None, 8, 8, 2)      34          ['to_one_shape[0][0]']
#
#  collapze_layers (GlobalAverage  (None, 2)           0           ['concentrate_out_C[0][0]']
#  Pooling2D)
#
#  softmax (Softmax)              (None, 2)            0           ['collapze_layers[0][0]']
#
# ==================================================================================================
# Total params: 135,154
# Trainable params: 134,962
# Non-trainable params: 192
# __________________________________________________________________________________________________

# %%
last_conv_layer = model.get_layer('concentrate_out_C')


model_fm = tf.keras.Model(inputs=model.inputs,
                          outputs=[
                              model.output,
                              last_conv_layer.output
                          ])

# %%
model_out, feature_maps = model_fm.predict(img)

# get rid of the batch channel, e.g. (1, 2) -> (2,)
feature_maps = numpy.squeeze(feature_maps)
model_out = numpy.squeeze(model_out)

print(f'Model out shape: {model_out.shape}')        # (2,)
print(f'Model features shape: {feature_maps.shape}')     # (8, 8, 2)
# Out:
# 1/1 [==============================] - 0s 15ms/step
# Model out shape: (2,)
# Model features shape: (8, 8, 2)

# %%
weights = numpy.array([0.0, 1.0])
print(weights.shape)
max_idx = numpy.argmax( model_out )
print(f"Max index: {max_idx} ({model_out[max_idx]*100:.2f}%)")
# Out:
# (2,)
# Max index: 1 (99.57%)

# %%
winning_weights = weights[max_idx]
print(winning_weights.shape) 

CAM = feature_maps.copy()
CAM = CAM[:, :, max_idx]
CAM = CAM/CAM.max()
CAM = (CAM*255).astype(numpy.uint8)

heatmap = cv2.resize(CAM, (img.shape[2], img.shape[1]))
heatmap_img = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
union_img = cv2.addWeighted(heatmap_img, 0.5, (img[0]*255).astype(numpy.uint8), 0.5, 0)
# Out:
# ()

# %%
pyplot.subplot(131)
pyplot.imshow(heatmap)
pyplot.subplot(132)
pyplot.imshow(img[0])
pyplot.subplot(133)
pyplot.imshow(union_img) #
pyplot.show()
